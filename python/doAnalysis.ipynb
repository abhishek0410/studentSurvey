# %%
import seaborn as sns
import pandas as pd

# %%
##Load the dataset
dataset = pd.read_csv('../data/survey2_ABS_v2.xls')

# %%
dataset
# Out:
#     Question1  Question2  Question3  Question4  Question5  Question6  \
# 0           0          1          0          1          0          0
# 1           1          1          0          1          0          0
# 2           0          1          1          1          0          0
# 3           2          1          1          1          0          1
# 4           0          0          0          0          0          0
# 5           1          1          1          1          0          0
# 6           2          1          1          1          0          0
# 7           2          0          1          0          0          0
# 8           0          1          1          1          0          0
# 9           0          0          1          1          1          1
# 10          1          1          1          1          1          1
# 11          2          1          1          1          0          0
# 12          2          1          1          1          0          0
# ...

# %%
#Do the visualization General Visualization
corr = dataset.corr()
x = corr[['Question8']]

# %%
sns.heatmap(corr)

# %%
corr
# Out:
#            Question1  Question2  Question3  Question4  Question5  Question6  \
# Question1   1.000000   0.014358   0.186871   0.268991  -0.246816  -0.214225
# Question2   0.014358   1.000000   0.281718   0.205879  -0.207704  -0.128124
# Question3   0.186871   0.281718   1.000000   0.297733  -0.216845  -0.013782
# Question4   0.268991   0.205879   0.297733   1.000000  -0.252379  -0.386078
# Question5  -0.246816  -0.207704  -0.216845  -0.252379   1.000000   0.409422
# Question6  -0.214225  -0.128124  -0.013782  -0.386078   0.409422   1.000000
# Question7   0.186871   0.056344   0.146667   0.189466  -0.563798  -0.234288
# Question8  -0.265908  -0.251976  -0.506842  -0.544705   0.549532   0.338983
#
#            Question7  Question8
# Question1   0.186871  -0.265908
# Question2   0.056344  -0.251976
# Question3   0.146667  -0.506842
# Question4   0.189466  -0.544705
# Question5  -0.563798   0.549532
# Question6  -0.234288   0.338983
# Question7   1.000000  -0.506842
# ...

# %% [markdown]
# # Pie Chart Anaysis Done in convertAliases.ipynb
