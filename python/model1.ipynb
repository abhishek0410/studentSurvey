# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy import loadtxt
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from keras.layers import Dense
from tensorflow import keras
import tensorflowjs as tfjs
import tensorflow as tf
import pickle
# import tens

# %%
##Load the dataset
dataset = pd.read_csv('../data/survey2.csv')

# %%
##View Data
dataset
# Out:
#      Question1  Question2  Question3  Question4  Question5  Question6  \
# 0            0          1          1          1          1          0
# 1            0          1          1          1          1          0
# 2            0          1          1          1          1          1
# 3            0          1          1          1          1          1
# 4            0          1          1          1          0          0
# ..         ...        ...        ...        ...        ...        ...
# 123          1          0          0          0          1          1
# 124          1          0          0          0          0          0
# 125          1          0          0          0          0          0
# 126          1          0          0          0          0          1
# 127          1          0          0          0          0          1
#
#      Question7  Question8
# 0            0          0
# 1            1          0
# 2            0          1
# 3            1          0
# 4            0          1
# ..         ...        ...
# 123          1          0
# 124          0          1
# 125          1          0
# 126          0          1
# 127          1          1
#
# [128 rows x 8 columns]

# %%
#1st - 7 rows of the dataset correspond to the intput variables and 8th variable corresponds to the output variable
X = dataset.iloc[:,:7]
Y = dataset.iloc[:,7]

# %%
#Splitting the data into 80:20
x_train, x_test, y_train, y_test = train_test_split(X, Y)

# %%
model = Sequential()
model.add(Dense(12, input_dim=7, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X, Y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 13/13 [==============================] - 0s 833us/step - loss: 0.6776 - accuracy: 0.5066
# Epoch 2/150
# 13/13 [==============================] - 0s 887us/step - loss: 0.6577 - accuracy: 0.6306
# Epoch 3/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6310 - accuracy: 0.7220
# Epoch 4/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6283 - accuracy: 0.7544
# Epoch 5/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6109 - accuracy: 0.7796
# Epoch 6/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6032 - accuracy: 0.7798
# Epoch 7/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5954 - accuracy: 0.8007
# Epoch 8/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5962 - accuracy: 0.7640
# Epoch 9/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5940 - accuracy: 0.7816
# Epoch 10/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5728 - accuracy: 0.7734
# Epoch 11/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5659 - accuracy: 0.7952
# Epoch 12/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5652 - accuracy: 0.7997
# Epoch 13/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5404 - accuracy: 0.7916
# Epoch 14/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5468 - accuracy: 0.7843
# Epoch 15/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5309 - accuracy: 0.7942
# Epoch 16/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5346 - accuracy: 0.8123
# Epoch 17/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4964 - accuracy: 0.8278
# Epoch 18/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4799 - accuracy: 0.8658
# Epoch 19/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4711 - accuracy: 0.8230
# Epoch 20/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4790 - accuracy: 0.8290
# Epoch 21/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4604 - accuracy: 0.8697
# Epoch 22/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4537 - accuracy: 0.8433
# Epoch 23/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4562 - accuracy: 0.8566
# Epoch 24/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4365 - accuracy: 0.8704
# Epoch 25/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4148 - accuracy: 0.8722
# Epoch 26/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3843 - accuracy: 0.8555
# Epoch 27/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3932 - accuracy: 0.8516
# Epoch 28/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3847 - accuracy: 0.8994
# Epoch 29/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4264 - accuracy: 0.8355
# Epoch 30/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4009 - accuracy: 0.8501
# Epoch 31/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3893 - accuracy: 0.8368
# Epoch 32/150
# 13/13 [==============================] - 0s 965us/step - loss: 0.3478 - accuracy: 0.8628
# Epoch 33/150
# 13/13 [==============================] - 0s 888us/step - loss: 0.4113 - accuracy: 0.8138
# Epoch 34/150
# 13/13 [==============================] - 0s 936us/step - loss: 0.4147 - accuracy: 0.8292
# Epoch 35/150
# 13/13 [==============================] - 0s 787us/step - loss: 0.3984 - accuracy: 0.8407
# Epoch 36/150
# 13/13 [==============================] - 0s 857us/step - loss: 0.3827 - accuracy: 0.8814
# Epoch 37/150
# 13/13 [==============================] - 0s 879us/step - loss: 0.3615 - accuracy: 0.8671
# Epoch 38/150
# 13/13 [==============================] - 0s 858us/step - loss: 0.3369 - accuracy: 0.9070
# Epoch 39/150
# 13/13 [==============================] - 0s 847us/step - loss: 0.3253 - accuracy: 0.9138
# Epoch 40/150
# 13/13 [==============================] - 0s 984us/step - loss: 0.3475 - accuracy: 0.8657
# Epoch 41/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3414 - accuracy: 0.8799
# Epoch 42/150
# 13/13 [==============================] - 0s 920us/step - loss: 0.2850 - accuracy: 0.8910
# Epoch 43/150
# 13/13 [==============================] - 0s 748us/step - loss: 0.3444 - accuracy: 0.8720
# Epoch 44/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3788 - accuracy: 0.8639
# Epoch 45/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3926 - accuracy: 0.8475
# Epoch 46/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3576 - accuracy: 0.8455
# Epoch 47/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2858 - accuracy: 0.9188
# Epoch 48/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3138 - accuracy: 0.8883
# Epoch 49/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3230 - accuracy: 0.8801
# Epoch 50/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3161 - accuracy: 0.8851
# Epoch 51/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3108 - accuracy: 0.8569
# Epoch 52/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3167 - accuracy: 0.8709
# Epoch 53/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2811 - accuracy: 0.9055
# Epoch 54/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3278 - accuracy: 0.8675
# Epoch 55/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3222 - accuracy: 0.8641
# Epoch 56/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8375
# Epoch 57/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3185 - accuracy: 0.8422
# Epoch 58/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3237 - accuracy: 0.8547
# Epoch 59/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2945 - accuracy: 0.8886
# Epoch 60/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2832 - accuracy: 0.8683
# Epoch 61/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3024 - accuracy: 0.9154
# Epoch 62/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3134 - accuracy: 0.8841
# Epoch 63/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2542 - accuracy: 0.9107
# Epoch 64/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2906 - accuracy: 0.8889
# Epoch 65/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3096 - accuracy: 0.8766
# Epoch 66/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3169 - accuracy: 0.8566
# Epoch 67/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3140 - accuracy: 0.8564
# Epoch 68/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3543 - accuracy: 0.8687
# Epoch 69/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3006 - accuracy: 0.8944
# Epoch 70/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2811 - accuracy: 0.9176
# Epoch 71/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2699 - accuracy: 0.9192
# Epoch 72/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3066 - accuracy: 0.8833
# Epoch 73/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3121 - accuracy: 0.8629
# Epoch 74/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2787 - accuracy: 0.9244
# Epoch 75/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3136 - accuracy: 0.8778
# Epoch 76/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2939 - accuracy: 0.8911
# Epoch 77/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2638 - accuracy: 0.8972
# Epoch 78/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2410 - accuracy: 0.9275
# Epoch 79/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2691 - accuracy: 0.9284
# Epoch 80/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2413 - accuracy: 0.9292
# Epoch 81/150
# 13/13 [==============================] - 0s 984us/step - loss: 0.3161 - accuracy: 0.8732
# Epoch 82/150
# 13/13 [==============================] - 0s 976us/step - loss: 0.3077 - accuracy: 0.8802
# Epoch 83/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3340 - accuracy: 0.8543
# Epoch 84/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3093 - accuracy: 0.8808
# Epoch 85/150
# 13/13 [==============================] - 0s 910us/step - loss: 0.2599 - accuracy: 0.9174
# Epoch 86/150
# 13/13 [==============================] - 0s 933us/step - loss: 0.2293 - accuracy: 0.9331
# Epoch 87/150
# 13/13 [==============================] - 0s 973us/step - loss: 0.2146 - accuracy: 0.9363
# Epoch 88/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2715 - accuracy: 0.9103
# Epoch 89/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2899 - accuracy: 0.8783
# Epoch 90/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2915 - accuracy: 0.8842
# Epoch 91/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3253 - accuracy: 0.8879
# Epoch 92/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2506 - accuracy: 0.9233
# Epoch 93/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2593 - accuracy: 0.9153
# Epoch 94/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2605 - accuracy: 0.9093
# Epoch 95/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2399 - accuracy: 0.9231
# Epoch 96/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2325 - accuracy: 0.9066
# Epoch 97/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2402 - accuracy: 0.9242
# Epoch 98/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2871 - accuracy: 0.8884
# Epoch 99/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2942 - accuracy: 0.8983
# Epoch 100/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2184 - accuracy: 0.9382
# Epoch 101/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2044 - accuracy: 0.9331
# Epoch 102/150
# 13/13 [==============================] - 0s 1000us/step - loss: 0.2095 - accuracy: 0.9365
# Epoch 103/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2497 - accuracy: 0.9085
# Epoch 104/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2228 - accuracy: 0.9212
# Epoch 105/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2070 - accuracy: 0.9276
# Epoch 106/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2009 - accuracy: 0.9376
# Epoch 107/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2407 - accuracy: 0.9300
# Epoch 108/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2280 - accuracy: 0.9172
# Epoch 109/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2415 - accuracy: 0.8888
# Epoch 110/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2023 - accuracy: 0.9395
# Epoch 111/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2417 - accuracy: 0.8758
# Epoch 112/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2515 - accuracy: 0.9002
# Epoch 113/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2535 - accuracy: 0.8950
# Epoch 114/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2011 - accuracy: 0.9313
# Epoch 115/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2816 - accuracy: 0.8647
# Epoch 116/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2401 - accuracy: 0.9098
# Epoch 117/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2286 - accuracy: 0.9155
# Epoch 118/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2163 - accuracy: 0.9044
# Epoch 119/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2526 - accuracy: 0.8976
# Epoch 120/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2119 - accuracy: 0.9231
# Epoch 121/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2132 - accuracy: 0.9049
# Epoch 122/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2012 - accuracy: 0.9365
# Epoch 123/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1993 - accuracy: 0.9154
# Epoch 124/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2214 - accuracy: 0.9057
# Epoch 125/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2115 - accuracy: 0.9182
# Epoch 126/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2052 - accuracy: 0.9231
# Epoch 127/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2048 - accuracy: 0.9364
# Epoch 128/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2173 - accuracy: 0.9084
# Epoch 129/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2036 - accuracy: 0.9341
# Epoch 130/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2556 - accuracy: 0.8937
# Epoch 131/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1823 - accuracy: 0.9285
# Epoch 132/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2006 - accuracy: 0.9154
# Epoch 133/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1857 - accuracy: 0.9232
# Epoch 134/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1958 - accuracy: 0.9217
# Epoch 135/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1706 - accuracy: 0.9325
# Epoch 136/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2124 - accuracy: 0.9072
# Epoch 137/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1807 - accuracy: 0.9358
# Epoch 138/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2255 - accuracy: 0.9068
# Epoch 139/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1361 - accuracy: 0.9573
# Epoch 140/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2057 - accuracy: 0.9180
# Epoch 141/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1944 - accuracy: 0.9285
# Epoch 142/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1317 - accuracy: 0.9625
# Epoch 143/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1699 - accuracy: 0.9242
# Epoch 144/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2124 - accuracy: 0.9199
# Epoch 145/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1894 - accuracy: 0.9245
# Epoch 146/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2037 - accuracy: 0.9041
# Epoch 147/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1721 - accuracy: 0.9335
# Epoch 148/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1760 - accuracy: 0.9431
# Epoch 149/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1704 - accuracy: 0.9207
# Epoch 150/150
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2027 - accuracy: 0.9239

# %%
_, accuracy = model.evaluate(x_test, y_test, verbose=0)

# %%
accuracy
# Out:
# 0.875

# %%
#Save the Model in h5
model.save("../ml_model/neurNet.h5")
model2 = keras.models.load_model("../ml_model/neurNet.h5")

# %%
#Run the commands in commandline (to convert the keras h5 model to tensorflowjs model)
#tensorflowjs_converter --input_format=keras /home/abhishek/Desktop/ALL_REACT_APPS/crud_firebase1/ml_model/neurNet.h5 /home/abhishek/Desktop/ALL_REACT_APPS/crud_firebase1/ml_model/qq/

# %%
#Load the tensorflowmodel
tf.loadLayersModel("../ml_model/qq/model.json")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-91505eafcf13> in <module>
#       1 #Load the tensorflowmodel
# ----> 2 tf.loadLayersModel("../ml_model/qq/model.json")
#
# AttributeError: module 'tensorflow' has no attribute 'loadLayersModel'

# %%
_, accuracy2 = model2.evaluate(x_test, y_test, verbose=0)

# %%
dataset.iloc[:,:8]

# %%
newDf = {'q1': [0], 'q2': [1],'q3': [1], 'q4': [1],'q5': [1], 'q6': [0],'q7':[0]}

# %%
df = pd.DataFrame(data=newDf)

# %%
model.predict(df)

# %%
tfjs.converters.save_keras_model(model, "../ml_model/neurNet3")

# %%
tf.keras.models.model_from_json("/home/abhishek/Desktop/ALL_REACT_APPS/crud_firebase1/ml_model/neurNet3/model.json")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-12-864ac1058b3f> in <module>
# ----> 1 tf.keras.models.model_from_json("/home/abhishek/Desktop/ALL_REACT_APPS/crud_firebase1/ml_model/neurNet3/model.json")
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/saving/model_config.py in model_from_json(json_string, custom_objects)
#     127       A Keras model instance (uncompiled).
#     128   """
# --> 129   config = json.loads(json_string)
#     130   from tensorflow.python.keras.layers import deserialize  # pylint: disable=g-import-not-at-top
#     131   return deserialize(config, custom_objects=custom_objects)
#
# ~/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
json_config = model.to_json()
new_model = keras.models.model_from_json(json_config)

# %%
new_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
_, accuracy2 = new_model.evaluate(x_test, y_test, verbose=0)

# %%
accuracy2

# %%
model_j = tf.keras.models.model_from_json(json_savedModel)
model_j.summary()

# %%
# Saving model to disk
pickle.dump(regressor, open('model.pkl','wb'))

# Loading model to compare the results
model = pickle.load(open('model.pkl','rb'))
print(model.predict([[2, 9, 6]]))

# %%
pwd
